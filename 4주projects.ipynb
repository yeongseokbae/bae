# %%
import pandas as pd 
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\USER\\projects\\bae\\실습자료\\train.csv',encoding = 'cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14095 entries, 0 to 14094
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14095 non-null  object
#  1   COMPONENT_ARBITRARY  14095 non-null  object
#  2   ANONYMOUS_1          14095 non-null  int64
#  3   YEAR                 14095 non-null  int64
#  4   SAMPLE_TRANSFER_DAY  14095 non-null  int64
#  5   ANONYMOUS_2          14095 non-null  int64
#  6   AG                   14095 non-null  int64
#  7   AL                   14095 non-null  int64
#  8   B                    14095 non-null  int64
#  9   BA                   14095 non-null  int64
#  10  BE                   14095 non-null  int64
#  11  CA                   14095 non-null  int64
#  12  CD                   12701 non-null  float64
#  13  CO                   14095 non-null  int64
#  14  CR                   14095 non-null  int64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  \
# 0      TRAIN_00000          COMPONENT3         1486  2011
# 1      TRAIN_00001          COMPONENT2         1350  2021
# 2      TRAIN_00002          COMPONENT2         2415  2015
# 3      TRAIN_00003          COMPONENT3         7389  2010
# 4      TRAIN_00004          COMPONENT3         3954  2015
# ...            ...                 ...          ...   ...
# 14090  TRAIN_14090          COMPONENT3         1616  2014
# 14091  TRAIN_14091          COMPONENT1         2784  2013
# 14092  TRAIN_14092          COMPONENT3         1788  2008
# 14093  TRAIN_14093          COMPONENT2         2498  2009
# 14094  TRAIN_14094          COMPONENT2         1902  2012
#
#        SAMPLE_TRANSFER_DAY  ANONYMOUS_2  AG   AL    B  BA  ...     U25  \
# 0                        7          200   0    3   93   0  ...     NaN
# 1                       51          375   0    2   19   0  ...     2.0
# ...

# %%
df.head(3)
# Out:
#             ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  SAMPLE_TRANSFER_DAY  \
# 0  TRAIN_00000          COMPONENT3         1486  2011                    7
# 1  TRAIN_00001          COMPONENT2         1350  2021                   51
# 2  TRAIN_00002          COMPONENT2         2415  2015                    2
#
#    ANONYMOUS_2  AG   AL   B  BA  ...  U25  U20   U14       U6       U4  V  \
# 0          200   0    3  93   0  ...  NaN  NaN   NaN      NaN      NaN  0
# 1          375   0    2  19   0  ...  2.0  4.0   6.0    216.0   1454.0  0
# 2          200   0  110   1   1  ...  0.0  3.0  39.0  11261.0  41081.0  0
#
#    V100    V40   ZN  Y_LABEL
# 0   NaN  154.0   75        0
# 1   NaN   44.0  652        0
# 2   NaN   72.6  412        1
#
# [3 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['ID', 'COMPONENT_ARBITRARY', 'ANONYMOUS_1', 'YEAR',
#        'SAMPLE_TRANSFER_DAY', 'ANONYMOUS_2', 'AG', 'AL', 'B', 'BA', 'BE', 'CA',
#        'CD', 'CO', 'CR', 'CU', 'FH2O', 'FNOX', 'FOPTIMETHGLY', 'FOXID', 'FSO4',
#        'FTBN', 'FE', 'FUEL', 'H2O', 'K', 'LI', 'MG', 'MN', 'MO', 'NA', 'NI',
#        'P', 'PB', 'PQINDEX', 'S', 'SB', 'SI', 'SN', 'SOOTPERCENTAGE', 'TI',
#        'U100', 'U75', 'U50', 'U25', 'U20', 'U14', 'U6', 'U4', 'V', 'V100',
#        'V40', 'ZN', 'Y_LABEL'],
#       dtype='object')

# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\USER\projects\bae\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
print(df.info())
print(df.describe())

# Boxplot을 그리는 함수 정의
def draw_boxplot(data, y, x=None, title="Boxplot", xlabel=None, ylabel=None):
    """
    Boxplot을 그리는 함수

    Parameters:
    - data (pd.DataFrame): 데이터프레임
    - y (str): y축에 사용할 컬럼 이름 (numerical data)
    - x (str, optional): x축에 사용할 컬럼 이름 (categorical data)
    - title (str, optional): 그래프 제목
    - xlabel (str, optional): x축 라벨
    - ylabel (str, optional): y축 라벨
    """
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=data, x=x, y=y)
    plt.title(title)
    plt.xlabel(xlabel if xlabel else x)
    plt.ylabel(ylabel if ylabel else y)
    plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14095 entries, 0 to 14094
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14095 non-null  object
#  1   COMPONENT_ARBITRARY  14095 non-null  object
#  2   ANONYMOUS_1          14095 non-null  int64
#  3   YEAR                 14095 non-null  int64
#  4   SAMPLE_TRANSFER_DAY  14095 non-null  int64
#  5   ANONYMOUS_2          14095 non-null  int64
#  6   AG                   14095 non-null  int64
#  7   AL                   14095 non-null  int64
#  8   B                    14095 non-null  int64
#  9   BA                   14095 non-null  int64
#  10  BE                   14095 non-null  int64
#  11  CA                   14095 non-null  int64
#  12  CD                   12701 non-null  float64
#  13  CO                   14095 non-null  int64
#  14  CR                   14095 non-null  int64
# ...

# %%
# Boxplot 그리기 - 실제 데이터프레임 사용
draw_boxplot(df, y='AG', x='COMPONENT_ARBITRARY', title="AG by Component", xlabel="Component", ylabel="AG")
